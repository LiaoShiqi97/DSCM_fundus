# %%
# Colab setup
# ! git clone https://github.com/biomedia-mira/deepscm.git
# ! pip install -r deepscm/requirements.txt
# ! pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# %cd deepscm/deepscm/experiments/plotting/ukbb/
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'deepscm/requirements.txt'
# WARNING: You are using pip version 20.2.3; however, version 22.1 is available.
# You should consider upgrading via the 'c:\users\shiqi\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from plotting_helper import plot_gen_intervention_range, interactive_plot

# %%
# import matplotlib
# matplotlib.use('TKAgg')
# import matplotlib.pyplot as plt

# %%
idx = 3
model_name = 'ConditionalVISEM'

interventions = [
    {'sex': 1.},
    {'age': 40.},
    {'age': 80.},
    {'brain_volume': 800000.},
    {'brain_volume': 1600000.},
    {'ventricle_volume': 11000.},
    {'ventricle_volume': 110000.},
]

plot_gen_intervention_range(model_name, interventions, idx, normalise_all=True, num_samples=32)

# %%
interactive_plot(model_name)
# Out:
# VBox(children=(IntSlider(value=0, description='Image #', max=4), VBox(children=(HBox(children=(FloatSlider(val…
